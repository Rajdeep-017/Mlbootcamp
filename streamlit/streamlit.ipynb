# %% [markdown]
# INTRO TO STREAMLIT
# Streamlit is an open source, uh, app framework for machine learning and data science projects.
# It allow you to create beautiful web applications for your machine learning and data science projects with, uh, Python scripts.
# Streamlit, it's a, it's an open source app framework for machine learning
#
# and data science projects.
#
# It allows you to create a beautiful web applications for your machine learning projects altogether.
