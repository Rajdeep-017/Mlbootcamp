# %%
1+1
# Out:
# 2

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# syntax refers to the set of rules that defines the combination of symbolsthat are considered to be correctly structured program in a language.In a simpler terms, syntax is about the correct arrangement of words and symbol in a code.
#
#  semantics refers to the meaning or interpretation of the symbol character and commands in a language.
# It is about what the code is supposed to do and it runs.
#
# Syntax is how we are able to arrange the words so that we write a code, and semantics refers to the
# interpretation.

# %%
name="raj"
Name="s"
print(name)
print(Name)
# Out:
# raj
# s

# %% [markdown]
# #indentation   Python uses indentation to define blocks of code.
#
# #Consistent use of space commonly for spaces or a tab is required.
#
# Indentation in Python is used to define the structure and hierarchy of the code.
#
# Unlike many other programming languages that uses braces to delimit block of codes, right.
#
# Python uses indentation to determine the grouping of statement.

# %%
age=32
if age>18:
    print("you are eligible for voting")
print(age)
# Out:
# you are eligible for voting
# 32

# %%
#line continuation
tot=1+2+4+-7+8+\
4+5+6
print(tot)
# Out:
# 23

# %%
#multi statement
a=10; b=20; c=a+b; print(c)

# %%
#semantics
#variable assignment    
a=10 # A IS INT
n="raj" # N IS STRING  
#type checking
type(a)
type(n)
# Out:
# str

# %%
var=10
print(type(var))
var="ran"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Variables
# variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program.
# In Python, variables are created when you assign a value to them, and they do not need explicit declaration to reserve memory space.
# The declaration happens automatically when you assign a value to a variable.

# %%
a=100
h=9.1
name="raj"
is_student=True 

print("age:", a)
print("height:", h)
print("name:", name)
print("is_student:", is_student)

# %% [markdown]
# naming convection
# varibles names should be descriptive
# they must start with a letter or an " _" and contain letter ,num ans underscore
# var names are case sensitive

# %%
first_name="raj"
last_name="kumar"
full_name=first_name+" "+last_name  
print("full_name:", full_name)

# %%
# PYTHON IS A DYNAMICALLY TYPED LANGUAGE
# type of variable is determined at runtime and can change during execution

#type conversion
num_str=123
num_str=str(num_str) # convert int to string
print(num_str)
# Out:
# 123

# %%
age='24'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
var=10
print(var,type(var))
var="hello"
print(var,type(var))
var=3.11
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.11 <class 'float'>

# %%
age=input("enter your age: ")
print("you entered:", age)
# Out:
# you entered: 12

# %% [markdown]
# Data Types
#  data types are a classification of data which tells the compiler or interpreter how the
# programmer intends to use the data.
# They determine the type of operation that can be performed on the data, the values that the data can
#
# take, and the amount of memory needed to store the data.
# data types ensure that the data is stored in a very efficient way.
#
# They help in performing correct operations on data.
#
# And proper use of data types can prevent errors and bugs in the program.

# %%
## int 
age=int(input("enter your age: "))  
print("you entered:", age)
type(age)
# Out:
# you entered: 12
# int

# %%
#float
height=float(input("enter your height: "))
print("you entered:", height)
type(height)
# Out:
# you entered: 1.55
# float

# %%
 #string 
name=input("enter your name: ")
print("you entered:", name) 
print(type(name))
# Out:
# you entered: raj
# <class 'str'>

# %%
#boolean 
is_true=True
type(is_true)
# Out:
# bool

# %%
is_true=bool()
print(is_true)
a=10; b=20
type(a==b)
# Out:
# False
# bool

# %%
res="hello"+str(12)
print(res)
# Out:
# hello12

# %%
str1="hello"    
str1.count("l")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 str1="hello"
# ----> 2 str1.count()
#
# TypeError: count expected at least 1 argument, got 0

# %% [markdown]
# OPERATORS
# multiple arithmetic operators like addition subtraction, multiple multiplication, division
#
# flow division modulus and exponential.
#
# Along with this we'll see comparison operators like equal to not equal to, greater than less than uh
#
# greater than or equal to, less than or equal to.
# logical operator: and or not

# %%
a=10
b=5
res=a+b
sub=a-b
m=a*b
div=a/b
floor_div=a//b
mod=a%b
expo=a**b
print(res)
print(sub)
print(m)
print(div)
print(floor_div) # remove the decimal part
print(mod)
print(expo)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
##comparison operator
print(a,b)
print(a==b) # equal to
print(a!=b) # not equal to
print(a>b) # greater than
print(a<b) # less than
print(a>=b) # greater than or equal to
print(a<=b) # less than or equal to
# Out:
# 10 5
# False
# True
# True
# False
# True
# False

# %%
str1="raj"
str2="Raj"
str1==str2
# Out:
# False

# %% [markdown]
# Logical Operators

# %%
x=True
y=False
print(x and y)  # True if both are True
print(x or y)   # True if at least one is True
print(not x)   # True if x is False, False if x is True
# Out:
# False
# True
# False
