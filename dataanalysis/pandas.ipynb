# %% [markdown]
# PANDAS
# pandas is a powerful data manipulation library in Python, widely used for data analysis and cleaning.
# It provides two primary data structures series and data frame.
# We'll understand the difference between series and data frame.
#
# A series is one dimensional array like object, while a data frame is a two dimensional size, mutable
#
# and potentially heterogeneous tabular data structure with labeled axis.
#
# Okay, so the basic difference between series and data frame is a series is the one dimensional like
#
# array object, like how we create a one dimensional array in NumPy.

# %%
import pandas as pd

# %%
#series Panda series is a one dimensional array like object that can hold any data type.It is similar to a column in a table.
data=[1,2,3,4,5]
series=pd.Series(data)
print("series",series)
print(type(series))
# Out:
# series 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>

# %%
#create a series from dictionaries
data={"a":1,"b":2,"c":3}
series=pd.Series(data)
print(series)
print(type(series))
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# <class 'pandas.Series'>

# %%
data=[1,2,3,4]
index=['a','b','c','d']
pd.Series(data,index=index)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
#dataframe
#create the datafraom from dict
data={
    'name':['kri','ojn','ma'],
    'age':[12,34,55],
    'city':['bangolar','pune','nyx']
}
df=pd.DataFrame(data)
print(df)
# Out:
#   name  age      city
# 0  kri   12  bangolar
# 1  ojn   34      pune
# 2   ma   55       nyx

# %%
import numpy as np
np.array(df)
# Out:
# array([['kri', 12, 'bangolar'],
#        ['ojn', 34, 'pune'],
#        ['ma', 55, 'nyx']], dtype=object)

# %%
#create df from dist of dict
data=[
    {'name':'kri','age':23,'city':'bangalore'},
    {'name':'joh','age':43,'city':'nyc'},
    {'name':'ani','age':53,'city':'pune'}
]
df=pd.DataFrame(data)
print(df)
# Out:
#   name  age       city
# 0  kri   23  bangalore
# 1  joh   43        nyc
# 2  ani   53       pune

# %%
# df['name']
df.loc[0]
df.iloc[0]
# Out:
# name          kri
# age            23
# city    bangalore
# Name: 0, dtype: object

# %%
df.at[1,'age']
# Out:
# np.int64(43)

# %%
df.at[2,'name']
# Out:
# 'ani'

# %%
df.iat[2,2]
# Out:
# 'pune'

# %%
#data manupilation with data frame
df['sal']=[4000,5000,6000]
df
# Out:
#   name  age       city   sal
# 0  kri   23  bangalore  4000
# 1  joh   43        nyc  5000
# 2  ani   53       pune  6000

# %%
#remove
df.drop('sal',axis=1,inplace=True)
#axis=1 for the column and inplace =true for the permanent deletion

# %%
df
# Out:
#   name  age       city   sal
# 0  kri   23  bangalore  4000
# 1  joh   43        nyc  5000
# 2  ani   53       pune  6000

# %%
df['age']=df['age']+1
df
# Out:
#   name  age       city
# 0  kri   25  bangalore
# 1  joh   45        nyc
# 2  ani   55       pune

# %%
df.drop(1,axis=0)
# Out:
#                       Formatted_Date        Summary Precip_Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# 5      2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent_Temperature_C  Humidity  Wind Speed (km/h)  \
# 0             9.472222                7.388889      0.89            14.1197
# ...

# %%
df=pd.read_csv(r"C:\Users\RAJDEEP\Downloads\archive (17)\weatherHistory.csv") 
df
# Out:
#                       Formatted_Date        Summary Precip_Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent_Temperature_C  Humidity  Wind Speed (km/h)  \
# 0             9.472222                7.388889      0.89            14.1197
# ...

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent_Temperature_C      Humidity  \
# count     96453.000000            96453.000000  96453.000000
# mean         11.932678               10.855029      0.734899
# std           9.551546               10.696847      0.195473
# min         -21.822222              -27.716667      0.000000
# 25%           4.688889                2.311111      0.600000
# 50%          12.000000               12.000000      0.780000
# 75%          18.838889               18.838889      0.890000
# max          39.905556               39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...
