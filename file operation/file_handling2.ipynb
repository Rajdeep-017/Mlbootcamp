# %%
#creating
import os
new_directory="package"
os.mkdir(new_directory)

# %%
#lsiting files and directories
items=os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'file_handling2.ipynb', 'package', 'read and write.ipynb']

# %%
##joinging paths

dir_name='folder'
file_name='file.txt'
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name='folder'
file_name='file.txt'
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# d:\ml\file operation\folder\file.txt

# %%
path='example1.txt'
if os.path.exists(path):
    print("the path exist")    
else:
    print("the path not exist")
# Out:
# the path not exist

# %%
#checking if a path is a file or directory
import os
path='example.txt'
if os.path.isfile(path):
    print("the path is file")
elif os.path.isdir(path):
    print("the path is directory")
else:
    print("the path is nothing")
# Out:
# the path is file

# %%
##gettinh absolute path
relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\ml\file operation\example.txt
