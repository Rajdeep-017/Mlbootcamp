# %% [markdown]
# The problem statement is trips and travel.
#
# Dot com company wants to enable and establish a viable business model to expand the customer base.
#
# One of the ways to expand the customer base is to introduce a new offering of packages.
#
# Currently, there are five types of packages that is uh, basic, standard, deluxe, super, deluxe
#
# King.
#
# Looking at the data of the last year, we observed 18 percentage of the customer purchased the package.
#
# However, the marketing cost was quite high because the customer was contacted at random without looking
#
# at the available information.
#
# The company is now planning to launch a new product wellness Tourism package.
#
# Now, wellness tourism is defined as travel that allows the traveler to maintain, enhance or kick start
#
# a healthy lifestyle and support or increase one's sense of well-being.
#
# However, this time, company wants to harness the available data of existing and potential customers
#
# to mark, uh, to the marketing expenditure.
#
# More efficient.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\RAJDEEP\Downloads\Travel.csv")

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
#Data cleaning
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64

# %%
df['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
df['Gender']=df['Gender'].replace('Fe Male','Female')
df['maritalStatus']=df['MaritalStatus'].replace('Single','unmarried')

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  ...  \
# 0        Salaried  Female                       3                3.0  ...
# 1        Salaried    Male                       3                4.0  ...
# 2     Free Lancer    Male                       3                4.0  ...
# 3        Salaried  Female                       2                3.0  ...
# 4  Small Business    Male                       2                3.0  ...
#
#   PreferredPropertyStar  MaritalStatus NumberOfTrips  Passport  \
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      2916
# Female    1972
# Name: count, dtype: int64

# %%
#missing values

feature_with_na=[features for features in df.columns if df[features].isnull().sum()>=1]
for feature in feature_with_na:
    print(feature,np.round(df[feature].isnull().mean()*100,5),'% missing values')
# Out:
# Age 4.62357 % missing values
# TypeofContact 0.51146 % missing values
# DurationOfPitch 5.13502 % missing values
# NumberOfFollowups 0.92062 % missing values
# PreferredPropertyStar 0.53191 % missing values
# NumberOfTrips 2.86416 % missing values
# NumberOfChildrenVisiting 1.35025 % missing values
# MonthlyIncome 4.76678 % missing values

# %%
df[feature_with_na].select_dtypes(exclude='object').describe()
# Out:
#                Age  DurationOfPitch  NumberOfFollowups  PreferredPropertyStar  \
# count  4662.000000      4637.000000        4843.000000            4862.000000
# mean     37.622265        15.490835           3.708445               3.581037
# std       9.316387         8.519643           1.002509               0.798009
# min      18.000000         5.000000           1.000000               3.000000
# 25%      31.000000         9.000000           3.000000               3.000000
# 50%      36.000000        13.000000           4.000000               3.000000
# 75%      44.000000        20.000000           4.000000               4.000000
# max      61.000000       127.000000           6.000000               5.000000
#
#        NumberOfTrips  NumberOfChildrenVisiting  MonthlyIncome
# count    4748.000000               4822.000000    4655.000000
# mean        3.236521                  1.187267   23619.853491
# std         1.849019                  0.857861    5380.698361
# ...

# %%
df.Age.fillna(df.Age.median(),inplace=True)
df.TypeofContact.fillna(df.TypeofContact.mode()[0],inplace=True)
df.DurationOfPitch.fillna(df.DurationOfPitch.median(),inplace=True)
df.NumberOfFollowups.fillna(df.NumberOfFollowups.mode()[0],inplace=True)
df.PreferredPropertyStar.fillna(df.PreferredPropertyStar.mode()[0],inplace=True)
df.NumberOfTrips.fillna(0,inplace=True)
df.NumberOfChildrenVisiting.fillna(df.NumberOfChildrenVisiting.mode()[0],inplace=True)
df.MonthlyIncome.fillna(df.MonthlyIncome.median(),inplace=True)
# Out:
# C:\Users\RAJDEEP\AppData\Local\Temp\ipykernel_31144\876565064.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df.Age.fillna(df.Age.median(),inplace=True)
# ...

# %%
df.head()
# Out:
#    ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0          1  41.0     Self Enquiry         3              6.0
# 1          0  49.0  Company Invited         1             14.0
# 2          1  37.0     Self Enquiry         1              8.0
# 3          0  33.0  Company Invited         1              9.0
# 4          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# ...

# %%
df.drop('CustomerID',inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.drop('CustomerID',inplace=True,axis=1)
#
# File d:\ml\myenv\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File d:\ml\myenv\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
#    4643             if labels is not None:
# ...

# %%
df.isnull().sum()
# Out:
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# maritalStatus                 0
# dtype: int64

# %%
df.head()
# Out:
#    ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0          1  41.0     Self Enquiry         3              6.0
# 1          0  49.0  Company Invited         1             14.0
# 2          1  37.0     Self Enquiry         1              8.0
# 3          0  33.0  Company Invited         1              9.0
# 4          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# ...

# %%
df['TotalVisiting']=df['NumberOfPersonVisiting']+df['NumberOfFollowups']
df.drop(columns=['NumberOfPersonVisiting','NumberOfFollowups'])
# Out:
#       ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0             1  41.0     Self Enquiry         3              6.0
# 1             0  49.0  Company Invited         1             14.0
# 2             1  37.0     Self Enquiry         1              8.0
# 3             0  33.0  Company Invited         1              9.0
# 4             0   NaN     Self Enquiry         1              8.0
# ...         ...   ...              ...       ...              ...
# 4883          1  49.0     Self Enquiry         3              9.0
# 4884          1  28.0  Company Invited         1             31.0
# 4885          1  52.0     Self Enquiry         3             17.0
# 4886          1  19.0     Self Enquiry         3             16.0
# 4887          1  36.0     Self Enquiry         1             14.0
#
#           Occupation  Gender ProductPitched  PreferredPropertyStar  \
# 0           Salaried  Female         Deluxe                    3.0
# ...
