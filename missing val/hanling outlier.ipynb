# %% [markdown]
# 5number and box plot

# %%
#mini, maxi,median,Q1,Q2,IQR

# %%
import numpy as np

# %%
lst_marks=[45,32,56,75,89,67,73,90,67,53,77,88]
mini,Q1,median,Q3,maxi=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
mini,Q1,maxi,Q3,median
# Out:
# (np.float64(32.0),
#  np.float64(55.25),
#  np.float64(90.0),
#  np.float64(79.75),
#  np.float64(70.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 24.5

# %%
lower_fence=Q1-1.5*IQR
higher_fence=Q3+1.5*IQR

# %%
lower_fence
# Out:
# np.float64(18.5)

# %%
higher_fence
# Out:
# np.float64(116.5)

# %%
lst_marks=[45,32,56,75,89,67,73,90,67,53,77,88]

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[45,32,56,75,89,67,73,90,67,53,77,88,120,340]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
