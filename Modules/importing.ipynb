# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import pi,sqrt
sqrt(16)
print(pi)
# Out:
# 3.141592653589793

# %%
from math import *
print(sqrt(16))
# Out:
# 4.0

# %%
#from the custom made module
from packages.maths import add
add(4,20)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 #from the custom made module
# ----> 2 from packages.maths import add
#       3 add(4,20)
#
# ImportError: cannot import name 'add' from 'packages.maths' (d:\ml\Modules\packages\maths.py)
