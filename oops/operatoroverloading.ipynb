# %% [markdown]
# __add__(self,other):adds two objects using the + operator
# __sub__(self,other):subs two objects using the - operator
# __gt__:greater than
# __mul__(self,oher):multiples two object using *
# __truediv__(self,other):divides two objects /
# __eq__(self,other):checks if two obj are equal using the == operator
# __lt__(self,other):check if one object is less than another <

# %%
#matths operator for vector
class vector:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __add__(self,other):
        return vector(self.x+other.x,self.y+other.y)
    def __sub__(self,other):
        return vector(self.x-other.x,self.y-other.y)
    def __mul__(self,other):
        return vector(self.x*other,self.y*other)
    def __eq__(aself,other):
        return vector(self.x==other.x,self.y==other.y)
    def __repr__(self):
        return f"vector({self.x} ,{self.y})"

#create objects of vector class
v1=vector(2,3)
v2=vector(4,5)
print(v1+v2)
print(v1-v2)
print(v1*3)
# Out:
# vector(6 ,8)
# vector(-2 ,-2)
# vector(6 ,9)

# %%
##overloading operator for complex no
class complexno:
    def __init__(self,real,img):
        self.real=real
        self.img=img
    def __add__(self,other):
        return complexno(self.real+other.real,self.img+other.img)
    def __sub__(self,other):
        return complexno(self.real-other.real,self.img-other.img)
    def __mul__(self,other):
        real_part=self.real*other.real-self.img*other.img
        img_part=self.real*other.img+self.img*other.real
        return complexno(real_part,img_part)
    def __repr__(self):
        return f"{self.real}+{self.img}i"

c1=complexno(2,3)
c2=complexno(1,4)
print(c1+c2)
# Out:
# 3+7i
